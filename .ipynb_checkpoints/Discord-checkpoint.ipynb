# %%
import click
import csv
import json
import os
import pandas as pd
import random
from pandas.core.frame import DataFrame
import requests
import sys
from datetime import date
import json
from itertools import chain


channel_id = '592829859890462739'
authcode = 'NDAzMjg1MDUzMjU5NTEzODU4.YOcxLQ._f3rQSQYM7HHuIUj_uTk0DymD4E'
def sort_it(x,ts):
    global dfn
    strs = x.split(' ')[1:7]
    del strs[4]
    strs.insert(0,ts)
    dfn.loc[len(dfn)] = strs
    
def get_messages(auth:str, channel_id:str) -> str:

    headers = {
    'authorization': auth
    }
    r = requests.get(f'https://discord.com/api/v8/channels/{channel_id}/messages/search?author_id=779478806867214367&offset=0', headers=headers)
    if "Unauthorized" in r.text:
        return None
    
    return r.text

def get_df():
    global channel_id
    global authcode
    
    dfn = pd.DataFrame(columns=['Time Stamp','Type','Stock','Indication','Expiry','Rate'])
    
    messages = get_messages(authcode,channel_id)
    messages = json.loads(messages)
    messages = messages['messages']
    
    df = pd.DataFrame(list(chain.from_iterable(messages)))
    df = df[['content','timestamp']]
    df = df[df['content'].str.contains('BTO | STC')]
    df.reset_index(inplace=True,drop=True)
    
    temp = df.apply(lambda row: sort_it(row['content'],row['timestamp']), axis=1)
    
    return dfn

# %%
df
# Out:
#                                               content  \
# 0   @everyone STC COST 420c 7/16 @ 1.05 not swingi...
# 1   @everyone STC BA 240c 7/16 @ 3.40 not swinging...
# 2   @everyone BTO BA 240c 7/16 @ 3.46 looking for ...
# 3   @everyone STC TSLA 650c 7/9 @ 8.55 on the rema...
# 4   @everyone STC TSLA 660c 7/9 @ 2.09 we got to t...
# 5   @everyone BTO COST 420c 7/16 @ 0.84 small posi...
# 6                  @everyone BTO TSLA 660c 7/9 @ 1.92
# 7   @everyone STC TSLA 650c 7/9 @ 6.55 half of the...
# 8   @everyone STC TSLA 650c 7/9 @ 4.58 partial on ...
# 9   @everyone BTO TSLA 650c 7/9 @ 3.40 risky lotto...
# 10  @everyone BTO RH 750c 7/16 @ 5.20 for a swing....
#
#                            timestamp
# 0   2021-07-09T19:58:42.553000+00:00
# 1   2021-07-09T19:57:46.507000+00:00
# 2   2021-07-09T17:29:36.571000+00:00
# 3   2021-07-09T16:54:47.865000+00:00
# 4   2021-07-09T16:51:20.154000+00:00
# 5   2021-07-09T14:50:20.148000+00:00
# 6   2021-07-09T14:10:13.403000+00:00
# 7   2021-07-08T16:47:38.372000+00:00
# 8   2021-07-08T15:57:38.657000+00:00
# 9   2021-07-08T13:40:14.889000+00:00
# 10  2021-07-07T19:10:35.921000+00:00
